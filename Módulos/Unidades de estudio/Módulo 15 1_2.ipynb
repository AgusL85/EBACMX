# %% [markdown]
# ## Interacción con datos de Internet

# %% [markdown]
# * Requests de data desde Internet
# * Crawling
# * Scraping de datos
# * Parseo de datos scrapeados de Internet- conversión a estructuras de datos
# * https://webscraping.pro/crawler-vs-scraper-vs-parser/

# %% [markdown]
# ## Antes de empezar

# %% [markdown]
# * Revisar lo que es HTML
# * Tener a la mano la especificación de las librerías a usarse: requests, BeautifulSoup, pprint

# %% [markdown]
# ### Requerimiento y Crawling de Data

# %%
# se debe importar la librería requests para poder traer data de internet
import requests
# URL es el sitio web que se va a scrpear
url= "https://ebac.mx/analista-de-datos"
data= requests.get(url)
# Se imprime la información del sitio web
print(data.text)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="utf-8"/>
#   <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/>
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <title>Curso online de ProfesiÃ³n: Analista de Datos - aprenda con EBAC</title>
#
#   <meta name="description" content="Curso online de IlustraciÃ³n Tradicional en 12 meses con certificado. EspecialÃ­zate como Analista de Datos e impulsa tu carrera en esta profesiÃ³n emergente." />
#   <meta name="keywords" content="" />
#   <meta property="og:url" content="https://ebac.mx/analista-de-datos"/>
#   <meta property="og:title" content="Curso online de ProfesiÃ³n: Analista de Datos - aprenda con EBAC"/>
#   <meta property="og:description" content="Curso online de IlustraciÃ³n Tradicional en 12 meses con certificado. EspecialÃ­zate como Analista de Datos e impulsa tu carrera en esta profesiÃ³n emergente."/>
#   <meta property="og:type" content="website"/>
# ...

# %%
from bs4 import BeautifulSoup
#obtiene todos los links de la página web
reqs = requests.get(url)
soup = BeautifulSoup(reqs.text,"html.parser")
urls=[]

for link in soup.find_all("a"):
    print(link.get("href"))
    urls.append(link.get("href"))
# Out:
# https://ebac.mx
# https://ebac.mx
# https://ebac.mx/cursos
# https://ebac.mx/webinars
# https://ebac.mx/about-us
# https://ebac.mx/blog
#
# https://ebac.mx/para-empresas/atraccion-de-talento
# tel:+525592252629
# http://lms.ebac.mx
# #price
# None
# #review:3
# #review:4
# #review:5
# #review:6
# #review:7
# None
# \"https://ebac.mx/upload/cms/ebac_tyc_alumnos_pag_cursos.pdf\"
# \"https://ebac.mx/upload/cms/ebac_aviso_de_privacidad_integral_alumnos.pdf\"
# https://ebac.mx/python-para-datos
# https://ebac.mx/cientifico-de-datos
# https://ebac.mx/sql-de-datos
# https://ebac.mx/backend-python
# https://ebac.mx/
# https://ebac.mx/cursos
# https://ebac.mx/analista-de-datos
# #price
# #price
# https://ebac.mx/
# https://wa.me/525592252629â
# tel:+525592252629â
# https://ebac.mx/upload/cms/ebac_aviso_de_privacidad_integral_alumnos.pdf
# https://ebac.mx/upload/cms/ebac_aviso_de_privacidad_integral_profesores.pdf
# https://ebac.mx/about-us
# https://ebac.mx/cursos
# https://ebac.mx/blog
# ...

# %%
type(urls)
# Out:
# list

# %%
urls[1:5]
# Out:
# ['https://ebac.mx',
#  'https://ebac.mx/cursos',
#  'https://ebac.mx/webinars',
#  'https://ebac.mx/about-us']

# %%
# Se debe analizar la estructura del HTML que se trae de cada página para entenderla y además poder obtener la información correcta.
# Se puede usar desde el navegador la vista "developer" para acceder a la estructura y entenderla.
# Se tiene un ejemplo además de usar "requests", se usa la librería BeautifulSoup, que permite
# una impresión más amigable de contenidos de este tipo
import  requests
from bs4 import BeautifulSoup
from pprint import pprint

# esto se usa para simular que somos humanos, y para que el sitio no se de cuenta que lo estamos scapping
# no siempre se debe utilizar, pero es recomendado
headers={
    "Access-Control-Allow-Origin": "*",
    "Access-Control-Allow-Methods":"GET",
    "Access-Control-Allow-Headers":"Content-Type",
    "Access-Control-Max-Age": "3600",
    "User-Agent":"Mozilla/5.0 (X11;Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0"
}

url= "https://notes.ayushsharma.in/technology"
data=requests.get(url, headers)

#Variable para guardar los artículos del sitio web
url_data=[]
html= BeautifulSoup(data.text,"html.parser")
articles=html.select("a.post-card")

for article in articles:
    title=article.select(".card-title")[0].get_text()
    excerpt= article.select(".card-text")[0].get_text()
    pub_date= article.select(".card-footer small")[0].get_text()

    url_data.append({"title": title, "excerpt": excerpt, "pub_date":pub_date})

pprint(url_data)
# Out:
# [{'excerpt': "Or: Etiquette and table manners for pinging other people's "
#              'servers.',
#   'pub_date': 'Nov 2022',
#   'title': 'Consuming APIs responsibly'},
#  {'excerpt': 'Add Jekyll posts into a series with series navigation.',
#   'pub_date': 'Feb 2022',
#   'title': 'Create a series of posts with navigation in Jekyll'},
#  {'excerpt': 'Implementing light and dark mode on your Bootstrap 5 + Jekyll '
#              'website.',
#   'pub_date': 'Jan 2022',
#   'title': 'A practical guide to light and dark mode in Bootstrap 5 and '
#            'Jekyll'},
#  {'excerpt': 'Celebrate 2022 with a shiny new file manager for Ubuntu!',
#   'pub_date': 'Jan 2022',
#   'title': 'Nemo - The Ubuntu file manager you didn’t know you needed'},
#  {'excerpt': "I've been working on a search engine for Fediverse instances!",
#   'pub_date': 'Jan 2022',
#   'title': 'Announcing Fediverse.to!'},
#  {'excerpt': 'Combine Jekyll and Netlify to create pretty URL redirects as '
# ...

# %%
type (url_data)
# Out:
# list

# %%
print(url_data[5]["excerpt"])
# Out:
# Combine Jekyll and Netlify to create pretty URL redirects as easy as 1-2-3.

# %%
# Encuentra todas las clases
page = requests.get(url, headers)
soup = BeautifulSoup(data.content, "html.parser")

class_list = set()
tags = {tag.name for tag in soup.find_all()}

#iterate all tags
for tag in tags:

    #find all elements of tag
    for i in soup.find_all(tag):

        #if tag has attribute of class
        if i.has_attr("class"):
            
            if len(i["class"]) !=0:
                class_list.add("".join(i["class"]))

print(class_list)
# Out:
# {'navbarfixed-topnavbar-expand-lg', 'fabfa-steam-symbolmx-2', 'fabfa-linkedin-inmx-2', 'container', 'nav-spacer', 'fasfa-atmx-2', 'rowrow-cols-1row-cols-md-4my-1g-3', 'fasfa-rss-squaremx-1', 'collapsenavbar-collapse', 'mx-1', 'fasfa-bellme-2', 'navbar-navms-auto', 'navbar-brand', 'nav-linkactive', 'meta-nav', 'fasfa-homemx-1', 'd-noned-sm-inline', 'fabfa-gitlabmx-2', 'navbar-toggler-icon', 'rowrow-cols-1row-cols-md-6g-3', 'container-fluid', 'display-6text-center', 'fasfa-donatemx-2', 'card-title', 'social-navbtnbtn-success', 'card-body', 'rowrow-cols-1row-cols-md-4g-3', 'card-texttext-muted', 'rowrow-cols-1', 'h-caption', 'nav-linktext-warning', 'nav-link', 'rowrow-cols-1row-cols-md-3g-3mt-0', 'display-5text-center', 'fabfa-mastodonmx-2', 'me-2', 'col', 'text-muted', 'fasfa-laugh-beammx-1', 'card-footertext-end', 'd-sm-none', 'rowrow-cols-1footer-logo', 'btnbtn-lgbtn-warning', 'text-center', 'd-noned-sm-inlinemx-1', 'card', 'fasfa-rss-squarems-2me-1', 'navbar-toggler', 'post-card', '
# ...

# %% [markdown]
# ## Scraping y Parsing de Datos

# %%
# Url es el sitio web que se va a scrapear
url= "https://listado.mercadolibre.com.mx/iphone#D[A:iphone]"
data = requests.get(url)
# se imprime la información del sitio web
print(data.text)
# Out:
# <!DOCTYPE html>
# <html lang="es-MX">
# ...

# %%
from bs4 import BeautifulSoup
import requests
headers={
    "Access-Control-Allow-Origin": "*",
    "Access-Control-Allow-Methods":"GET",
    "Access-Control-Allow-Headers":"Content-Type",
    "Access-Control-Max-Age": "3600",
    "User-Agent":"Mozilla/5.0 (X11;Ubuntu; Linux x86_64; rv:52.0) Gecko/20100101 Firefox/52.0"
}

url= "https://listado.mercadolibre.com.mx/iphone#D[A:iphone]"
response = requests.get(url, headers=headers)
pprint (response.content[0:10000])
# Out:
# (b'\n<!DOCTYPE html>\n<html lang="es-MX">\n<head><link rel="preconnect" href="'
#  b'https://www.google-analytics.com"/><link rel="preconnect" href="https://www.'
#  b'google.com"/><link rel="preconnect" href="https://data.mercadolibre.com"/><l'
#  b'ink rel="preconnect" href="https://http2.mlstatic.com"/><link rel="preconnec'
#  b't" href="https://stats.g.doubleclick.net"/><link rel="preconnect" href="http'
#  b's://analytics.mercadolibre.com.mx"/><link rel="preconnect" href="https://ana'
#  b'lytics.mercadolibre.com"/><link rel="preconnect" href="https://www.google.co'
#  b'm.mx"/><script type=\'text/javascript\'>window.NREUM||(NREUM={});NREUM.inf'
#  b'o = {"agent":"","beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","'
#  b'licenseKey":"NRBR-6b78f6637d1702173e8","applicationID":"1729522169","agentTo'
#  b'ken":null,"applicationTime":624.508376,"transactionName":"YlZQYEVZC0QEV0BZV1'
#  b'scd0xHSgBEFl5HH39wZx0bHQ==","queueTime":0,"ttGuid":"6ac8c67a4a8e6fd4"}; (win'
# ...

# %%
# vamos a buscar las clases de la página web
# un ejemplo simple con BeautifulSoup
url= "https://listado.mercadolibre.com.mx/iphone#D[A:iphone]"
data = requests.get(url, headers)

html= BeautifulSoup(data.text, "lxml")

for item in html.select(".ui-search-layout__item"):
    try:
        print("---------------------------")
        title= item.select("h2")[0].get_text()

        print(title)
    except Exception as e:
        #raise e
        print("")
# Out:
# ---------------------------
# Apple iPhone 14 (128 GB) - Morado
# ---------------------------
# Apple iPhone 11 (64 GB) - Negro
# ---------------------------
# Apple iPhone 12 Pro Max (128 GB) - Grafito
# ---------------------------
#  iPhone X 64 GB gris espacial
# ---------------------------
# iPhone 12 Mini Smartphone Apple 64gb 4gb Ram 5.4
# ---------------------------
# iPhone 11 Pro 256 Gb Verde Medianoche
# ---------------------------
# Apple iPhone 14 (256 GB) - Azul
# ---------------------------
# Teléfono Móvil Blackview Bl8800 Pro Dual Sim, 128 Gb, 8 Gb D
# ---------------------------
# Apple iPhone 12 Pro Max (128 Gb) - Grafito Original Liberado Grado A
# ---------------------------
# Apple iPhone 12 (64 Gb) - Negro
# ---------------------------
#  iPhone XS Max 256 Gb Gris Espacial
# ---------------------------
#  iPhone 8 64 GB gris espacial
# ---------------------------
# Apple iPhone SE (2da generación) 64 GB - Negro
# ---------------------------
# ...

# %%
# Ahora se hace un ejemplo con el mismo sitio de Mercado Libre
# Además se explica cómo obtener la información de cada tarjeta
import numpy as np
url= "https://listado.mercadolibre.com.co/inmuebles/apartamentos/venta/bogota-dc/"
data = requests.get(url,headers)

html = BeautifulSoup(data.text, "lxml")
#genera las listas para la información del sitio web
arr_price = []
arr_dpt_size = []
arr_num_habs =[]
arr_location =[]
i=0

for item in html.select(".ui-search-layout__item"):
    try:
        price = item.select("span.price-tag-fraction")[0].get_text()
        dpt_size = item.select("li.ui-search-card-attributes__attribute")[0].get_text()
        num_habs = item.select("li.ui-search-card-attributes__attribute")[1].get_text()
        #location = item.select("h2.ui-search-item__title.ui-search-item__group__element")[0].get_text()

        # Asigna los valores del sitio web a las listas correspondientes
        arr_price+= [price]
        arr_dpt_size+= [dpt_size]
        arr_num_habs+= [num_habs]
        #arr_location += [location]

    except Exception as e:
        raise e

# %%
type (arr_price)
# Out:
# list

# %%
# Reemplazo strings con enteros
new_arr_price=[]
for price in arr_price:
    new_price=price.replace(".","")
    new_arr_price.append(int(new_price))

# %%
new_arr_price[3]
# Out:
# 250000000

# %%
# se puede graficar
import matplotlib.pyplot as plt
plt.bar(range(len(new_arr_price)), new_arr_price)
# Out:
# <BarContainer object of 48 artists>

# %%
# Se generan los datos en un archivo CSV
import csv
# Importar la función "os" para leer el directorio actual
import os
os.chdir("/Users/Agus/Documents/Cursos/Analista de Datos/Parte II/Módulo 15")

# abre el archivo donde se guardarán las listas
resultFile= open("mercadolibre.csv", "w")

# Write data to file
for i in range(0, len(arr_dpt_size)):
    resultFile.write(arr_price[i]+","+arr_dpt_size[i] +","+ arr_num_habs[i]+" \n")
resultFile.close()
